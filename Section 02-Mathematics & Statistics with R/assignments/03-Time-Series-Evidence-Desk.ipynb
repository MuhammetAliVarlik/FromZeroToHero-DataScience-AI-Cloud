# %% [markdown]
# # Mission 03: Time-Series Evidence Desk
# A logistics company needs to plan inventory for a product whose demand changes by season, promotion, and special events. Your job is to read the time pattern, quantify the signal, and produce a forecast that operations can use.

# %% [markdown]
# ## What You Must Deliver
# Use the time-series ideas from the section to analyze trend, seasonality, sampling, and forecasting quality. The result should help the operations team decide how much stock to hold next month.

# %%
dates <- seq(as.Date("2024-01-01"), by = "month", length.out = 24)
demand <- c(82, 79, 85, 88, 91, 96, 101, 98, 94, 92, 89, 87, 90, 88, 93, 97, 102, 107, 110, 108, 103, 99, 95, 93)
ts_data <- data.frame(date = dates, demand = demand)
head(ts_data)

# %%
analyze_demand <- function(data) {
  # Add decomposition, forecasting logic, and an error metric here.
  ...
}
demand_report <- analyze_demand(ts_data)
demand_report

# %% [markdown]
# ## Mission Rules
# 1. Show the trend you see in the demand series.
# 2. Comment on seasonal or repeating behavior.
# 3. Produce a forecast for the next period or next few periods.
# 4. Evaluate how good your forecast is using an error measure.

# %% [markdown]
# ## Submission Checklist
# - The demand pattern is described clearly.
# - A forecast is generated.
# - Forecast accuracy or error is discussed.
