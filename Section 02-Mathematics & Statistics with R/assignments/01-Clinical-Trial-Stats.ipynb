# %% [markdown]
# # Mission 01: Clinical Trial Stats
# A hospital analytics team received patient outcome data from three treatment groups, but the decision committee wants a clear answer before the next round of funding. Your job is to turn the raw study notes into a statistically defensible conclusion the committee can trust.

# %% [markdown]
# ## What You Must Deliver
# Use probability, hypothesis testing, comparison of groups, assumption checks, effect size, and post-hoc analysis to answer a real clinical question. Keep the work practical: the committee wants a recommendation, not a glossary.

# %%
set.seed(42)
trial_data <- data.frame(
  patient_id = 1:36,
  treatment = rep(c("Control", "Drug_A", "Drug_B"), each = 12),
  recovery_days = c(rnorm(12, 14, 2), rnorm(12, 11, 2), rnorm(12, 9, 2)),
  side_effect_score = c(rnorm(12, 2, 1), rnorm(12, 4, 1), rnorm(12, 5, 1))
)
head(trial_data)

# %%
analyze_trial <- function(data) {
  # Replace this with your full workflow: summaries, tests, assumptions, and effect sizes.
  ...
}
trial_report <- analyze_trial(trial_data)
trial_report

# %% [markdown]
# ## Mission Rules
# 1. Compare the three groups using a test you justify.
# 2. Check assumptions before trusting the result.
# 3. Report the size of the effect, not only the p-value.
# 4. If the overall result is significant, add a post-hoc comparison.

# %% [markdown]
# ## Submission Checklist
# - Your analysis uses the correct comparison test for the scenario.
# - Assumption checks are included.
# - The final interpretation is written like a real recommendation.
