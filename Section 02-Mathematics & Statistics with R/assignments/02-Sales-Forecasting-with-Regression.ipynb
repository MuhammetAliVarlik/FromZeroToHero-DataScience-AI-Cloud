# %% [markdown]
# # Mission 02: Sales Forecasting with Regression
# A retail chain wants to predict next quarter's revenue from pricing, advertising, and store traffic data. Your task is to build a regression-based decision tool that can tell leadership what matters most and where the model still falls short.

# %% [markdown]
# ## What You Must Deliver
# Use simple and multiple linear regression, correlation analysis, diagnostics, and model comparison. Focus on whether the model is useful in a business setting and not just whether it runs.

# %%
set.seed(7)
sales_data <- data.frame(
  revenue = c(120, 134, 128, 150, 162, 155, 172, 180, 190, 200),
  ad_spend = c(10, 12, 11, 15, 17, 16, 19, 20, 21, 24),
  foot_traffic = c(220, 240, 235, 260, 275, 270, 290, 300, 315, 330),
  discount_rate = c(2, 3, 2, 4, 5, 4, 6, 6, 7, 8)
)
summary(sales_data)

# %%
build_sales_model <- function(data) {
  # Compare at least one simple model and one multiple regression model.
  ...
}
sales_result <- build_sales_model(sales_data)
sales_result

# %% [markdown]
# ## Mission Rules
# 1. Explain which predictor appears most important.
# 2. Check residual behavior and basic model assumptions.
# 3. Compare at least two model specifications.
# 4. Include a business-friendly forecast recommendation.

# %% [markdown]
# ## Submission Checklist
# - A regression model is fit and interpreted.
# - Diagnostics or residual checks are shown.
# - The final answer is framed as a decision memo.
