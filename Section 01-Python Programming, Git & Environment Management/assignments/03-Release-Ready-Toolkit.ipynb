# %% [markdown]
# # Mission 03: Release-Ready Toolkit
#
# A product team has built a small analytics tool, but launch week is coming and the code is slow, the environment is messy, and the project is not ready for collaboration. Your job is to turn the prototype into a versioned, reproducible, and faster toolkit that the team can ship.

# %% [markdown]
# ## What You Must Deliver
#
# This mission is about performance, environment management, and team workflow. Use virtual environments, Poetry, Git fundamentals, and GitHub-style collaboration habits while improving the speed of the Python code.
#
# The final result should feel like something a team could actually maintain.

# %%
from time import perf_counter

weekly_events = [
    {"day": "Mon", "tickets": 34, "severity": "low"},
    {"day": "Tue", "tickets": 51, "severity": "high"},
    {"day": "Wed", "tickets": 22, "severity": "medium"},
    {"day": "Thu", "tickets": 65, "severity": "high"},
    {"day": "Fri", "tickets": 19, "severity": "low"},
]

def build_report_slow(items):
    report = []
    for item in items:
        if item["tickets"] >= 30:
            report.append(f"{item['day']}: {item['tickets']} tickets")
    return report


def build_report_fast(items):
    ...

# %%
def benchmark(function, data):
    start = perf_counter()
    result = function(data)
    elapsed = perf_counter() - start
    return result, elapsed


def compare_approaches(data):
    """Measure two implementations and explain the tradeoff."""
    ...

# %% [markdown]
# ## Mission Rules
#
# 1. Create a virtual environment before installing anything.
# 2. Use Poetry to define dependencies and make the project reproducible.
# 3. Initialize a Git repository, work on a feature branch, and make at least one clean commit.
# 4. Profile the slow code first, then optimize only the parts that matter.
# 5. Keep the code readable after the speedup. Faster code that nobody understands is a failed mission.
#
# ### Practical Workflow Hint
# Think of the repo as the team handoff point. Your notebook should describe how the project moves from local setup to a review-ready branch.

# %% [markdown]
# ## Collaboration Checklist
#
# - Add a short README section that explains how another teammate can run the toolkit.
# - Keep imports organized and remove anything unused.
# - Use clear commit messages such as `add report benchmark` or `refactor report builder`.
# - Pretend a teammate opened a pull request and left review comments. Update the code so the review would pass.

# %% [markdown]
# ## Submission Checklist
#
# - The notebook shows a before-and-after comparison for the slow function.
# - The environment setup is reproducible.
# - The Git workflow is documented clearly.
# - The final toolkit looks like something a real team could hand off and maintain.
