# %% [markdown]
# # Mission 01: Operation Market Pulse
#
# A neighborhood grocery chain called PulseMart is losing money every night because its order intake is messy, inconsistent, and full of surprises. Your job is to turn raw shop-floor requests into a clean nightly report that the store manager can trust before opening time.

# %% [markdown]
# ## What You Must Deliver
#
# Build a small Python workflow that reads order requests, validates them, fixes common mistakes, groups them into useful summaries, and writes the final report to a file. The manager wants a practical result, not a lecture.
#
# You should use lists, tuples, dictionaries, sets, comprehensions, loops, conditions, functions, basic input/output, and exception handling.

# %%
raw_orders = [
    {"store": "North", "item": "milk", "qty": "12", "priority": "high"},
    {"store": "North", "item": "bread", "qty": "8", "priority": "medium"},
    {"store": "South", "item": "eggs", "qty": "invalid", "priority": "high"},
    {"store": "East", "item": "apples", "qty": "20", "priority": "low"},
    {"store": "North", "item": "milk", "qty": "5", "priority": "high"},
    {"store": "West", "item": "coffee", "qty": "3", "priority": "urgent"},
]

allowed_priorities = {"low", "medium", "high", "urgent"}
critical_items = {"milk", "eggs", "bread"}

# %%
def parse_order(record):
    """Return a cleaned order dictionary or raise a clear error."""
    ...


def clean_orders(records):
    """Filter invalid rows, normalize text, and convert quantities safely."""
    ...


def summarize_orders(orders):
    """Return store totals, critical item counts, and priority breakdowns."""
    ...


def write_report(path, summary):
    """Write the nightly report to a text file."""
    ...

# %%
def prompt_for_shift_name():
    try:
        shift_name = input("Enter the shift name for the report: ")
        if not shift_name.strip():
            raise ValueError("Shift name cannot be empty")
        return shift_name.strip()
    except ValueError as error:
        print(f"Problem: {error}")
        return "Unknown Shift"

# %% [markdown]
# ## Mission Rules
#
# 1. Reject rows with missing keys, non-numeric quantities, or invalid priorities.
# 2. Keep the code readable and split into small functions.
# 3. Use at least one list comprehension and one dictionary comprehension in your final solution.
# 4. Write a report that the store manager can read in under one minute.
#
# ### Bonus Challenge
# Add a tiny command-line interaction that asks the user whether the store should prioritize critical items first. If they say yes, reorder the summary accordingly.

# %% [markdown]
# ## Submission Checklist
#
# - Your notebook runs from top to bottom without crashing.
# - The report file is created successfully.
# - Invalid rows are handled without stopping the full workflow.
# - The final output clearly explains what the store should stock first.
