# %% [markdown]
# # Mission 03: ACID and ETL Control Room
# A finance team is moving daily transactions from an operational system into a reporting database, and the process must never lose money or duplicate records. Your mission is to design a safe workflow that demonstrates transactions, integrity checks, and recovery thinking.

# %% [markdown]
# ## What You Must Deliver
# Use transactions, constraints, stored logic, access control awareness, backup/recovery planning, and data-loading hygiene to keep the pipeline reliable. The scenario should read like a production handoff, not a classroom exercise.

# %%
BEGIN TRANSACTION;
INSERT INTO accounts (account_id, balance) VALUES (1, 500);
INSERT INTO accounts (account_id, balance) VALUES (2, 300);
-- Simulate a transfer and decide whether to COMMIT or ROLLBACK.
...
COMMIT;

# %%
-- Sketch a stored procedure or trigger that protects a business rule.
...

# %% [markdown]
# ## Mission Rules
# 1. Show how the pipeline stays consistent when something fails.
# 2. Include at least one constraint or validation rule.
# 3. Explain what should be backed up and how recovery would work.
# 4. State which users or roles should be allowed to run the workflow.

# %% [markdown]
# ## Submission Checklist
# - Transaction behavior is clearly handled.
# - Integrity and recovery concerns are addressed.
# - The workflow looks production-aware.
