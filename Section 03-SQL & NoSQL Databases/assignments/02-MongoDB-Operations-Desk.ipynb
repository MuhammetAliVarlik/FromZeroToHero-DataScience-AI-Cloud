# %% [markdown]
# # Mission 02: MongoDB Operations Desk
# A fast-growing support platform stores tickets, users, and message history as documents instead of rows. Your mission is to design the document model, write the CRUD workflow, and pull useful analytics out of nested data.

# %% [markdown]
# ## What You Must Deliver
# Use MongoDB fundamentals: document design, collection structure, nested fields, querying, aggregation, and operational thinking. The result should explain why this data belongs in a document store.

# %%
tickets = [
    {"ticket_id": 1, "user": {"id": 101, "region": "EU"}, "status": "open", "priority": "high"},
    {"ticket_id": 2, "user": {"id": 102, "region": "US"}, "status": "closed", "priority": "low"},
    {"ticket_id": 3, "user": {"id": 101, "region": "EU"}, "status": "open", "priority": "medium"},
]
tickets

# %%
def create_ticket_document(ticket):
    """Shape a ticket document for insertion into MongoDB."""
    ...
def summarize_tickets(collection):
    """Aggregate open tickets by region and priority."""
    ...

# %% [markdown]
# ## Mission Rules
# 1. Show a document structure that matches the support workflow.
# 2. Include create, read, update, and delete operations in some form.
# 3. Query nested fields at least once.
# 4. Use aggregation to answer an operational question.

# %% [markdown]
# ## Submission Checklist
# - Document design is consistent.
# - CRUD behavior is demonstrated.
# - Aggregation output answers a real support question.
