# %% [markdown]
# # Mission 01: E-Commerce Analytics Warehouse
# An online store wants a reporting warehouse that can answer revenue, retention, and product performance questions without slowing down the app database. Your job is to design the schema and write the queries that turn raw sales into a decision-ready analytics view.

# %% [markdown]
# ## What You Must Deliver
# Use relational design, normalization, JOINs, GROUP BY, window functions, subqueries or CTEs, and basic performance thinking. The final result should feel like a warehouse reporting layer rather than a pile of disconnected queries.

# %%
CREATE TABLE customers (
    customer_id INTEGER PRIMARY KEY,
    customer_name TEXT NOT NULL,
    region TEXT NOT NULL
);
CREATE TABLE orders (
    order_id INTEGER PRIMARY KEY,
    customer_id INTEGER NOT NULL,
    order_date DATE NOT NULL,
    total_amount DECIMAL(10, 2) NOT NULL,
    FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
);

# %%
-- Write a query that returns monthly revenue by region, plus a running total.
...

# %% [markdown]
# ## Mission Rules
# 1. Design a schema that supports reporting without duplication.
# 2. Use at least one JOIN and one window function.
# 3. Include one query that answers a business question in plain English.
# 4. Suggest one index that would help your slowest query.

# %% [markdown]
# ## Submission Checklist
# - Tables are normalized enough for the scenario.
# - Queries answer the warehouse questions clearly.
# - A performance improvement is proposed.
