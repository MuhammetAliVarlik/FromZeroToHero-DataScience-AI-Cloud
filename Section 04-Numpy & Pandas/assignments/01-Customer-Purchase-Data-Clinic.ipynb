# %% [markdown]
# # Mission 01: Customer Purchase Data Clinic
# A subscription business exported customer purchases from three broken systems, and the dataset is full of missing values, inconsistent labels, and duplicate records. Your job is to clean the mess and turn it into a trustworthy customer summary for the growth team.

# %% [markdown]
# ## What You Must Deliver
# Use NumPy and Pandas to clean the data, repair missing values, standardize text, and produce a reliable summary of customer behavior. Focus on a practical cleaning workflow rather than isolated theory.

# %%
import numpy as np
import pandas as pd
raw = pd.DataFrame({
    'customer_id': [101, 102, 103, 104, 105, 105],
    'segment': ['vip', 'standard', None, 'vip', 'standard', 'standard'],
    'order_value': [120.0, np.nan, 75.5, 220.0, 89.0, 89.0],
    'purchase_date': ['2024-01-05', '2024-01-08', None, '2024-01-10', '2024-01-12', '2024-01-12']
})
raw

# %%
def clean_customer_data(frame: pd.DataFrame) -> pd.DataFrame:
    """Clean missing values, standardize labels, and remove duplicates."""
    ...
cleaned = clean_customer_data(raw)
cleaned

# %% [markdown]
# ## Mission Rules
# 1. Identify what should be dropped and what should be imputed.
# 2. Convert data types correctly before analysis.
# 3. Show a short summary of customer value by segment.
# 4. Keep the final dataset tidy enough for downstream analysis.

# %% [markdown]
# ## Submission Checklist
# - Missing and duplicate data are handled sensibly.
# - Labels and types are standardized.
# - The cleaned frame is ready for reporting.
