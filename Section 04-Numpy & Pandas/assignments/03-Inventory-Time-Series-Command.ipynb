# %% [markdown]
# # Mission 03: Inventory Time-Series Command
# A warehouse team tracks daily inventory levels and wants to know when stock starts drifting into danger territory. Your job is to reshape the timeline, smooth the noise, and flag the points where the supply plan needs intervention.

# %% [markdown]
# ## What You Must Deliver
# Use date handling, resampling, rolling windows, vectorized calculations, and performance-aware Pandas or NumPy operations. The final notebook should help operations react before stockouts happen.

# %%
dates = pd.date_range('2024-01-01', periods=30, freq='D')
inventory = pd.DataFrame({
    'date': dates,
    'units_on_hand': np.array([220, 218, 215, 213, 210, 208, 205, 203, 200, 198, 196, 195, 194, 191, 188, 186, 184, 182, 179, 177, 175, 173, 171, 168, 166, 163, 161, 159, 156, 154])
})
inventory.head()

# %%
def inspect_inventory(frame: pd.DataFrame) -> pd.DataFrame:
    """Add useful time-based features and rolling metrics."""
    ...
inventory_view = inspect_inventory(inventory)
inventory_view

# %% [markdown]
# ## Mission Rules
# 1. Convert the date column correctly.
# 2. Add at least one rolling or resampled view.
# 3. Detect a threshold where inventory becomes risky.
# 4. Use vectorized operations instead of row-by-row loops whenever possible.

# %% [markdown]
# ## Submission Checklist
# - Time-based features are in place.
# - Inventory risk is identified clearly.
# - The output is efficient and easy to follow.
