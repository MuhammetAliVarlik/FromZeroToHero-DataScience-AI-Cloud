# %% [markdown]
# # Mission 02: Multi-Source Data Integration Hub
# A product analytics team receives separate files for customers, orders, and catalog data, and leadership wants one combined view before the next planning meeting. Your task is to merge the sources correctly and expose the patterns hidden across them.

# %% [markdown]
# ## What You Must Deliver
# Use joins, merges, concatenation, grouping, and reshaping to build a single analysis-ready dataset. The final result should answer a real business question about revenue, region, or product mix.

# %%
customers = pd.DataFrame({
    'customer_id': [1, 2, 3],
    'region': ['North', 'South', 'West']
})
orders = pd.DataFrame({
    'order_id': [11, 12, 13, 14],
    'customer_id': [1, 1, 2, 3],
    'product_id': [100, 101, 100, 102],
    'amount': [40, 55, 60, 80]
})
products = pd.DataFrame({
    'product_id': [100, 101, 102],
    'category': ['Book', 'Game', 'Accessory']
})

# %%
def build_combined_view(customers: pd.DataFrame, orders: pd.DataFrame, products: pd.DataFrame) -> pd.DataFrame:
    """Merge the sources into one reporting table."""
    ...
combined = build_combined_view(customers, orders, products)
combined

# %% [markdown]
# ## Mission Rules
# 1. Join the sources in a way that preserves the correct business meaning.
# 2. Produce at least one pivot, groupby result, or aggregated summary.
# 3. Identify the top category by revenue in each region.
# 4. Explain any duplicate or unmatched keys you discover.

# %% [markdown]
# ## Submission Checklist
# - The merged table is correct and easy to inspect.
# - Aggregations answer a useful business question.
# - Any data quality issues are explained.
